# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %%
n = 5
in_means = [20, 25, 30, 35, 27]
out_means = [25, 35, 34, 20, 25]
in_std = [2, 3, 4, 1, 2]
out_std = [3, 5, 2, 3, 3]

indexes = np.arange(n)
width = 0.5

p1 = plt.bar(indexes, in_means, width, yerr=in_std)
p2 = plt.bar(indexes, out_means, width, bottom=in_means, yerr=out_std)

plt.ylabel('分值')
plt.title('不同组用户下国内外用户分值')
plt.xticks(indexes, ['组' + str(i) for i in range(1, 6)])
plt.yticks(np.arange(0, 81, 10))

plt.legend((p1[0], p2[0]), ('国内', '国外'))
